# %% [markdown]
# <a href="https://colab.research.google.com/github/ronnief1/Polyp-Segmentation/blob/main/image_mask_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
import os

# %%
num_images = len(os.listdir('/content/drive/MyDrive/ColabNotebooks/AppliedDeepLearning/Kvasir-SEG/images/'))
print('Number of images:', num_images)
# Out:
# Number of images: 1000

# %%
num_masks = len(os.listdir('/content/drive/MyDrive/ColabNotebooks/AppliedDeepLearning/Kvasir-SEG/masks/'))
print('Number of masks:', num_masks)
# Out:
# Number of masks: 1000

# %%
img = cv2.imread('/content/drive/MyDrive/ColabNotebooks/AppliedDeepLearning/Kvasir-SEG/images/cju0qkwl35piu0993l0dewei2.jpg')
plt.imshow(img, cmap='gray')

# %%
img = cv2.imread('/content/drive/MyDrive/ColabNotebooks/AppliedDeepLearning/Kvasir-SEG/masks/cju0qkwl35piu0993l0dewei2.jpg')
plt.imshow(img, cmap='gray')
